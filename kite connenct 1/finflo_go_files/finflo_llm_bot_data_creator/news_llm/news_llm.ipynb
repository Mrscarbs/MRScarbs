# %%
import pandas as pd 
import mysql.connector
from langchain.indexes import VectorstoreIndexCreator
from langchain.document_loaders import TextLoader
import os

# %%
conn = mysql.connector.connect(
        host="localhost",
        user="root",
        password="Karma100%",
        database="finflo_base_db"
    )
mycur = conn.cursor()
mycur.callproc("stp_get_api_config", [6,])



for result in mycur.stored_results():
    my_result = result.fetchall()
    result1 = my_result[0]
conn.commit()
conn.close()
api_key = result1[0]

os.environ["OPENAI_API_KEY"] = api_key

loader = TextLoader("news_docs.txt", encoding='utf-8')

# %%
index = VectorstoreIndexCreator().from_loaders([loader])
# Out:
# C:\Users\karma\AppData\Roaming\Python\Python312\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
index.query("give me 10 lines news for bitcoin give me the url for the news")
# Out:
# '\n1. "Bitcoin reaches new all-time high of $61,000 after Coinbase and Block report blockbuster earnings" - https://qz.com/bitcoin-price-coinbase-block-earnings-1851454065\n2. "Analyst predicts major correction for Bitcoin and stocks as interest rates rise" - https://readwrite.com/bitcoin-price-drop-interest-rate-expectations/\n3. "Investors withdraw over $500 million from publicly traded American Bitcoin companies" - https://readwrite.com/bitcoin-altcoins-dip-on-iran-israel-tensions/\n4. "Bitcoin and altcoins experience dip as tensions between Iran and Israel escalate" - https://readwrite.com/bitcoin-altcoins-dip-on-iran-israel-tensions/\n5. "Bitcoin\'s market cap surpasses $1 trillion for the first time" - https://www.cnbc.com/2021/02/19/bitcoin-btc-price-hits-1-trillion-market-cap-for-first-time.html\n6. "Tesla invests $1.5 billion in Bitcoin, plans to accept it as payment in the future" - https://www.cnbc.com/2021/02/08/tesla-buys-1point5-billion-in-bitcoin.html\n7'
